# %%
import gymnasium as gym
import airfoil_env
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy

# %%
env = gym.make('AirfoilEnv-v0', n_params=10, max_steps=10, scale_actions = 0.15, airfoil_seed = [0.1*np.ones(10), -0.1*np.ones(10), 0.0],
                    delta_reward=False, cl_reward = True, cl_reset = 0.2, efficiency_param = 1, cl_wide = 20, render_mode="human")
model = PPO.load("../models/230424/230424_2M_LearningStudy_0.001_Gamma0.99/logs/best_model.zip", env=env)
#model = PPO.load("16042024_NewRewardCl_4_DeltaReward", env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Evaluate the agent
# NOTE: If you use wrappers with your environment that modify rewards,
#       this will be reflected here. To evaluate with original rewards,
#       wrap environment in a "Monitor" wrapper before other wrappers.
mean_reward, std_reward = evaluate_policy(model, env=env, n_eval_episodes=15, deterministic=True)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:408.54 +/- 56.84

# %%
# Enjoy trained agent
vec_env = model.get_env()
obs = vec_env.reset()

# %%
for i in range(20):
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = vec_env.step(action)
    print(f"Step: {i}, Action: {action}, Reward: {rewards}, Done: {dones}, Info: {info}")
    vec_env.render()
# Out:
# Step: 0, Action: [[ 0.18883377  0.1857535   0.09391598  0.284716    0.4255886   0.46111923
#    0.5515662   0.6162677   0.3130653   0.24474278 -0.29678312 -0.15250492
#   -0.12398504 -0.22572461 -0.27986717 -0.2448225  -0.38408607 -0.34333372
#   -0.15678756 -0.14610752 -0.06666896]], Reward: [-100.], Done: [False], Info: [{'step': 1, 'efficiency': 0.0, 'cl': 0.0, 'TimeLimit.truncated': False}]
# Step: 1, Action: [[ 0.24647912  0.24728055  0.1656585   0.30425644  0.46019995  0.47049648
#    0.5450855   0.6050973   0.32436788  0.26721004 -0.36765215 -0.17610049
#   -0.16016673 -0.26241964 -0.29028416 -0.26164207 -0.41571337 -0.36767563
#   -0.17925881 -0.18554968 -0.0402106 ]], Reward: [-100.], Done: [False], Info: [{'step': 2, 'efficiency': 0.0, 'cl': 0.0, 'TimeLimit.truncated': False}]
# Step: 2, Action: [[ 0.30030346  0.30067682  0.23377672  0.32088366  0.49688065  0.48336962
#    0.54129416  0.5933968   0.3354522   0.2876806  -0.43043542 -0.19672778
#   -0.19561489 -0.2962165  -0.30053082 -0.27614293 -0.44760913 -0.3909251
#   -0.20246242 -0.22431819 -0.01229178]], Reward: [18.94732], Done: [False], Info: [{'step': 3, 'efficiency': 21.176499685272287, 'cl': 0.12542469023909575, 'TimeLimit.truncated': False}]
# Step: 3, Action: [[ 0.35019085  0.3457973   0.29777563  0.33401397  0.53440577  0.49816746
#    0.5386849   0.58035517  0.3457067   0.30550212 -0.4857599  -0.21459225
#   -0.2299821  -0.32693768 -0.31021148 -0.28817677 -0.47916055 -0.41249943
#   -0.2255304  -0.2620088   0.01695569]], Reward: [18.023851], Done: [False], Info: [{'step': 4, 'efficiency': 19.11285328460535, 'cl': 0.14584049239920882, 'TimeLimit.truncated': False}]
# Step: 4, Action: [[ 0.39614472  0.38292307  0.35735694  0.3434341   0.57187825  0.5137057
#    0.53640735  0.56562567  0.35475597  0.32024056 -0.5341862  -0.22993726
#   -0.26290354 -0.3544279  -0.31905773 -0.29769626 -0.50994724 -0.43203044
#   -0.24789979 -0.2981801   0.04726887]], Reward: [14.731606], Done: [False], Info: [{'step': 5, 'efficiency': 15.171478383084148, 'cl': 0.1616450652590964, 'TimeLimit.truncated': False}]
# Step: 5, Action: [[ 0.43823123  0.4126053   0.41235116  0.34918845  0.60863066  0.52909696
#    0.5340608   0.54918945  0.3623969   0.33166784 -0.57622373 -0.24302372
#   -0.29404    -0.37858006 -0.3269081  -0.30473632 -0.53968406 -0.44932956
#   -0.2692269  -0.33241794  0.07829198]], Reward: [10.531682], Done: [False], Info: [{'step': 6, 'efficiency': 10.746196281418692, 'cl': 0.1682479826959843, 'TimeLimit.truncated': False}]
# Step: 6, Action: [[ 0.47652236  0.4354999   0.46264842  0.35146248  0.6441222   0.54365104
#    0.5314652   0.53120255  0.36852646  0.33971965 -0.61232287 -0.25410303
#   -0.3230983  -0.39933792 -0.33366945 -0.30938447 -0.5681496  -0.46432826
#   -0.28928635 -0.3643787   0.10961905]], Reward: [5.9547663], Done: [False], Info: [{'step': 7, 'efficiency': 6.26973281852006, 'cl': 0.14923496707949258, 'TimeLimit.truncated': False}]
# Step: 7, Action: [[ 0.5110744   0.4522673   0.50817263  0.35051173  0.67788833  0.55681914
#    0.52851456  0.5118958   0.37309915  0.3444566  -0.6428803  -0.26340425
#   -0.34984416 -0.41669703 -0.33929083 -0.31176165 -0.5951485  -0.4770342
#   -0.30790478 -0.39381248  0.14083283]], Reward: [2.1912708], Done: [False], Info: [{'step': 8, 'efficiency': 2.6957238236565497, 'cl': 0.09821956889727756, 'TimeLimit.truncated': False}]
# Step: 8, Action: [[ 0.54194117  0.46353903  0.54889554  0.34663674  0.7095394   0.5681824
#    0.52511966  0.49152824  0.37611443  0.34603775 -0.6682616  -0.27113616
#   -0.37411088 -0.43070954 -0.34375602 -0.31201562 -0.62051004 -0.48750767
#   -0.32493615 -0.42057112  0.17153668]], Reward: [0.23230572], Done: [False], Info: [{'step': 9, 'efficiency': 0.4328850617103098, 'cl': 0.023588833315449476, 'TimeLimit.truncated': False}]
# Step: 9, Action: [[ 0.56920207  0.46992046  0.5848649   0.34017867  0.73878235  0.5774591
#    0.52120435  0.47037435  0.37761873  0.34470105 -0.6888313  -0.27749717
#   -0.3958056  -0.44148958 -0.347084   -0.31032008 -0.6441045  -0.49585098
#   -0.340262   -0.44460663  0.2013798 ]], Reward: [-0.20227656], Done: [ True], Info: [{'step': 10, 'efficiency': -0.8134090406728195, 'cl': -0.06378004442046803, 'episode': {'r': -129.589473, 'l': 10, 't': 7.021018}, 'TimeLimit.truncated': False, 'terminal_observation': {'airfoil': array([ 0.7028385 ,  0.6544395 ,  0.64981246,  0.5987924 ,  0.9801875 ,
#         0.8803101 ,  0.9030104 ,  0.92723995,  0.62966555,  0.5697939 ,
#        -0.89550054, -0.44185406, -0.5064327 , -0.6298811 , -0.578599  ,
#        -0.5375048 , -0.88061696, -0.7480773 , -0.4815333 , -0.5607927 ,
#         0.09700704], dtype=float32), 'cl_target': array([0.2], dtype=float32), 'boxes': array([0.5219711 , 0.00645321, 0.5394817 , 0.09194045], dtype=float32)}}]
# Step: 10, Action: [[ 0.41747436  0.5563603   0.57424515  0.6617621   0.6634345   0.52218217
#    0.40553525  0.32910573  0.15400888  0.4192959  -0.553522   -0.323069
#   -0.36842445 -0.43022135 -0.36840773 -0.22954138 -0.32065997 -0.25349966
#   -0.05332892 -0.34586903  0.03792096]], Reward: [5.534587], Done: [False], Info: [{'step': 1, 'efficiency': 8.772309700811824, 'cl': 0.04824637671259091, 'TimeLimit.truncated': False}]
# Step: 11, Action: [[ 0.45199183  0.55735195  0.60421526  0.6399257   0.6909757   0.56372267
#    0.44852173  0.33782238  0.18464145  0.43155235 -0.5879316  -0.32831356
#   -0.4020087  -0.44315025 -0.39928818 -0.24739772 -0.3774363  -0.30416015
#   -0.0945223  -0.39121005  0.06376047]], Reward: [11.92908], Done: [False], Info: [{'step': 2, 'efficiency': 14.55609870590429, 'cl': 0.1002425509257322, 'TimeLimit.truncated': False}]
# Step: 12, Action: [[ 0.4862461   0.5552336   0.63433     0.6164383   0.7175146   0.5999964
#    0.48274904  0.34008664  0.21130928  0.43765175 -0.6207189  -0.33251545
#   -0.43247315 -0.45318177 -0.42542386 -0.2614353  -0.43008238 -0.34805545
#   -0.1315721  -0.43410286  0.09192541]], Reward: [13.867888], Done: [False], Info: [{'step': 3, 'efficiency': 15.528424924059152, 'cl': 0.12480152839951164, 'TimeLimit.truncated': False}]
# Step: 13, Action: [[ 0.51929426  0.5498137   0.6634347   0.5912132   0.742474    0.63068414
#    0.5089905   0.33660698  0.23397093  0.43781948 -0.6506368  -0.3355198
#   -0.45935392 -0.4600748  -0.44685155 -0.271706   -0.47827116 -0.38522583
#   -0.16453643 -0.4739641   0.12171879]], Reward: [13.365285], Done: [False], Info: [{'step': 4, 'efficiency': 14.48648213503428, 'cl': 0.13653533078046332, 'TimeLimit.truncated': False}]
# Step: 14, Action: [[ 0.5504813   0.5413958   0.69075924  0.5645386   0.7656184   0.6558391
#    0.52844423  0.3284519   0.25283626  0.43260795 -0.6768843  -0.33733532
#   -0.4824167  -0.46384057 -0.4638618  -0.27846125 -0.52200544 -0.4160516
#   -0.19369723 -0.5103808   0.15240355]], Reward: [10.027255], Done: [False], Info: [{'step': 5, 'efficiency': 10.92627839219543, 'cl': 0.13447755035273667, 'TimeLimit.truncated': False}]
# Step: 15, Action: [[ 0.5793177   0.5304096   0.71575385  0.53681654  0.786828    0.6756729
#    0.54229337  0.3167215   0.2682054   0.4227352  -0.6989997  -0.3380525
#   -0.50162005 -0.4646555  -0.4768666  -0.28204766 -0.56143373 -0.44107592
#   -0.2193603  -0.54314363  0.18328814]], Reward: [2.3319962], Done: [False], Info: [{'step': 6, 'efficiency': 3.4128117392208104, 'cl': 0.06201234431556335, 'TimeLimit.truncated': False}]
# Step: 16, Action: [[ 0.6054479   0.5172571   0.7380372   0.50845134  0.80602187  0.69047326
#    0.5515336   0.30239874  0.2803995   0.40897334 -0.71679693 -0.33780673
#   -0.51707035 -0.46279544 -0.4863229  -0.28284687 -0.5967664  -0.46089867
#   -0.24177688 -0.5722306   0.21377748]], Reward: [-0.49923867], Done: [False], Info: [{'step': 7, 'efficiency': -4.272972642249875, 'cl': -0.12764163193472933, 'TimeLimit.truncated': False}]
# Step: 17, Action: [[ 0.6286632   0.50229025  0.75739974  0.47982436  0.8231624   0.70059484
#    0.55696654  0.28631574  0.28974718  0.39208496 -0.73032326 -0.33676633
#   -0.5289822  -0.45859364 -0.4926986  -0.28124824 -0.62825644 -0.47612625
#   -0.26114464 -0.5977696   0.24339515]], Reward: [-0.00247952], Done: [False], Info: [{'step': 8, 'efficiency': -8.15525334360739, 'cl': -0.43633135843384774, 'TimeLimit.truncated': False}]
# Step: 18, Action: [[ 0.6489078   0.48583144  0.7738058   0.45129564  0.83827513  0.7064611
#    0.5592463   0.2691617   0.2965835   0.37278837 -0.73981375 -0.33512577
#   -0.5376443  -0.45241168 -0.49645662 -0.27763385 -0.6561951  -0.487348
#   -0.27763465 -0.6199985   0.27178615]], Reward: [-6.505224e-08], Done: [False], Info: [{'step': 9, 'efficiency': -8.344534101944332, 'cl': -0.766169805508033, 'TimeLimit.truncated': False}]
# Step: 19, Action: [[ 0.6662655   0.468191    0.787374    0.42320073  0.851453    0.70855206
#    0.5589233   0.25149724  0.30124468  0.35173714 -0.7456365  -0.33309463
#   -0.54338926 -0.4446163  -0.498042   -0.27236784 -0.6809043  -0.49512148
#   -0.29141557 -0.6392243   0.29870707]], Reward: [-2.1679774e-12], Done: [ True], Info: [{'step': 10, 'efficiency': -7.499147885816763, 'cl': -1.0014993940324612, 'episode': {'r': 56.554373, 'l': 10, 't': 9.307897}, 'TimeLimit.truncated': False, 'terminal_observation': {'airfoil': array([ 0.9331135 ,  0.88962024,  1.1409032 ,  0.92102003,  1.2528636 ,
#         1.0681268 ,  0.87148064,  0.5647253 ,  0.47094208,  0.716087  ,
#        -1.1081896 , -0.6006399 , -0.8160075 , -0.7800312 , -0.78313303,
#        -0.50270295, -0.8878017 , -0.71013445, -0.38934836, -0.869184  ,
#         0.2518025 ], dtype=float32), 'cl_target': array([0.2], dtype=float32), 'boxes': array([0.3388203 , 0.02045374, 0.19030194, 0.08849047], dtype=float32)}}]
