# %%
import gymnasium as gym
import airfoil_env
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy

# %%
env = gym.make('AirfoilEnv-v0', n_params=10, max_steps=10, scale_actions = 0.15, airfoil_seed = [0.1*np.ones(10), -0.1*np.ones(10), 0.0],
                    delta_reward=False, cl_reward = True, cl_reset = 0.2, efficiency_param = 1, cl_wide = 20, render_mode="human")
model = PPO.load("../models/230424/230424_2M_LearningStudy_0.001_Gamma0.99/logs/best_model.zip", env=env)
#model = PPO.load("16042024_NewRewardCl_4_DeltaReward", env=env)
# Out:
# c:\Users\pablo\Documents\GitHub\2d-geometry-optimization-\new_venv\Lib\site-packages\stable_baselines3\common\save_util.py:167: UserWarning: Could not deserialize object clip_range. Consider using `custom_objects` argument to replace this object.
# Exception: code() argument 13 must be str, not int
#   warnings.warn(
# c:\Users\pablo\Documents\GitHub\2d-geometry-optimization-\new_venv\Lib\site-packages\stable_baselines3\common\save_util.py:167: UserWarning: Could not deserialize object lr_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: code() argument 13 must be str, not int
#   warnings.warn(
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Evaluate the agent
# NOTE: If you use wrappers with your environment that modify rewards,
#       this will be reflected here. To evaluate with original rewards,
#       wrap environment in a "Monitor" wrapper before other wrappers.
mean_reward, std_reward = evaluate_policy(model, env=env, n_eval_episodes=15, deterministic=True)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:408.54 +/- 56.84

# %%
# Enjoy trained agent
vec_env = model.get_env()
obs = vec_env.reset()

# %%
for i in range(20):
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = vec_env.step(action)
    print(f"Step: {i}, Action: {action}, Reward: {rewards}, Done: {dones}, Info: {info}")
    vec_env.render()
# Out:
# Step: 0, Action: [[ 0.20582993  0.16507319  0.16953976  0.35640097  0.50260675  0.54083467
#    0.5647092   0.62989163  0.35203454  0.30331248 -0.3683604  -0.1652627
#   -0.15213881 -0.26683122 -0.32189637 -0.26384962 -0.40828732 -0.34487444
#   -0.14597313 -0.21509622 -0.0419111 ]], Reward: [-100.], Done: [False], Info: [{'step': 1, 'efficiency': 0.0, 'cl': 0.0, 'TimeLimit.truncated': False}]
# Step: 1, Action: [[ 0.270225    0.2286253   0.24642967  0.37158322  0.5381247   0.5516181
#    0.5582647   0.6170676   0.36729708  0.32034594 -0.44200665 -0.19180422
#   -0.1910248  -0.30428126 -0.3367065  -0.2824456  -0.4487047  -0.3726488
#   -0.16936907 -0.25441957 -0.01218481]], Reward: [-100.], Done: [False], Info: [{'step': 2, 'efficiency': 0.0, 'cl': 0.0, 'TimeLimit.truncated': False}]
# Step: 2, Action: [[ 0.3298989   0.28275776  0.3187772   0.38335887  0.5752323   0.56520706
#    0.55367416  0.6029277   0.38160443  0.3352968  -0.5064273  -0.21490708
#   -0.2283343  -0.3379694  -0.3504952  -0.29775965 -0.48845232 -0.39838904
#   -0.19314165 -0.29334825  0.01879849]], Reward: [25.395452], Done: [False], Info: [{'step': 3, 'efficiency': 26.01992122949005, 'cl': 0.16514866351276125, 'TimeLimit.truncated': False}]
# Step: 3, Action: [[ 0.3846927   0.32746506  0.3859655   0.3911843   0.6125955   0.5799413
#    0.54953736  0.58678126  0.3943056   0.34740746 -0.5622217  -0.2348139
#   -0.26369366 -0.36773425 -0.36288995 -0.30970562 -0.52687144 -0.42152703
#   -0.21641009 -0.33122385  0.05079373]], Reward: [23.57032], Done: [False], Info: [{'step': 4, 'efficiency': 23.57042417056539, 'cl': 0.2004715040821825, 'TimeLimit.truncated': False}]
# Step: 4, Action: [[ 0.43461546  0.3632681   0.4476528   0.39497262  0.6492916   0.59463793
#    0.5452244   0.5684954   0.4050501   0.35623783 -0.6099943  -0.25182414
#   -0.29674748 -0.39348325 -0.37369043 -0.31834036 -0.56355757 -0.44178498
#   -0.23866467 -0.36740792  0.08341581]], Reward: [17.072512], Done: [False], Info: [{'step': 5, 'efficiency': 17.15278219863582, 'cl': 0.21531449923649537, 'TimeLimit.truncated': False}]
# Step: 5, Action: [[ 0.47974795  0.39095134  0.50365937  0.39491007  0.6846486   0.60844225
#    0.5405329   0.54826486  0.41368032  0.36161113 -0.65033627 -0.26625085
#   -0.32719597 -0.41520074 -0.38281608 -0.3238185  -0.59825295 -0.45908996
#   -0.25961578 -0.40135798  0.11620227]], Reward: [9.035509], Done: [False], Info: [{'step': 6, 'efficiency': 9.086769563725149, 'cl': 0.18318159061024875, 'TimeLimit.truncated': False}]
# Step: 6, Action: [[ 0.52017945  0.41135743  0.5538909   0.39131135  0.71812826  0.6207102
#    0.5354109   0.52642155  0.42014536  0.3635435  -0.68380374 -0.27838698
#   -0.35481018 -0.43293932 -0.39025348 -0.3263501  -0.6307625  -0.47349006
#   -0.27906778 -0.432668    0.14867242]], Reward: [2.06591], Done: [False], Info: [{'step': 7, 'efficiency': 2.6363078265522333, 'cl': 0.08958973026730321, 'TimeLimit.truncated': False}]
# Step: 7, Action: [[ 0.5560031   0.42529702  0.598329    0.3845529   0.7492917   0.6309659
#    0.52982736  0.50333685  0.42446578  0.36219096 -0.7109254  -0.2884987
#   -0.37944114 -0.4468172  -0.39603305 -0.3261794  -0.6609289  -0.48510468
#   -0.29685986 -0.46108082  0.18037395]], Reward: [-0.24717785], Done: [False], Info: [{'step': 8, 'efficiency': -0.8445802954534997, 'cl': -0.04786404460868532, 'TimeLimit.truncated': False}]
# Step: 8, Action: [[ 0.5873438   0.43353477  0.63705695  0.37505442  0.7778154   0.6389003
#    0.52374744  0.47938937  0.42672777  0.35781443 -0.732228   -0.29683438
#   -0.40102565 -0.45702025 -0.40022564 -0.32357746 -0.68864506 -0.49410176
#   -0.31285685 -0.48648345  0.21091637]], Reward: [-0.09049705], Done: [False], Info: [{'step': 9, 'efficiency': -2.2459425324705484, 'cl': -0.2007220530389605, 'TimeLimit.truncated': False}]
# Step: 9, Action: [[ 0.6143887   0.43680286  0.67028326  0.36327213  0.80351216  0.64437467
#    0.51714796  0.45495465  0.42708254  0.3507502  -0.7482576  -0.30363646
#   -0.4195857  -0.46380118 -0.40294284 -0.31883818 -0.71387434 -0.5006861
#   -0.3269596  -0.50889015  0.23999149]], Reward: [-0.00725839], Done: [ True], Info: [{'step': 10, 'efficiency': -2.640540361088653, 'cl': -0.342981626184527, 'episode': {'r': -123.205229, 'l': 10, 't': 24.332503}, 'TimeLimit.truncated': False, 'terminal_observation': {'airfoil': array([ 0.7574388 ,  0.61976993,  0.77973765,  0.67099017,  1.0916871 ,
#         0.99634486,  0.9127115 ,  0.92762965,  0.70185906,  0.6187766 ,
#        -1.0021843 , -0.47383294, -0.55209965, -0.68291175, -0.65769243,
#        -0.5636297 , -0.95925057, -0.75875455, -0.46583778, -0.66279644,
#         0.1492603 ], dtype=float32), 'cl_target': array([0.2], dtype=float32), 'boxes': array([ 5.30859053e-01, -1.02414915e-05,  3.94621849e-01,  9.91510525e-02],
#       dtype=float32)}}]
# Step: 10, Action: [[ 0.17482226  0.08194473  0.13844083  0.33850655  0.5126483   0.5866801
#    0.5997062   0.6883658   0.4076688   0.31013566 -0.36158127 -0.13515943
#   -0.12032005 -0.24664514 -0.3225697  -0.269884   -0.4222732  -0.35240003
#   -0.15250073 -0.22318551 -0.03993212]], Reward: [-100.], Done: [False], Info: [{'step': 1, 'efficiency': 0.0, 'cl': 0.0, 'TimeLimit.truncated': False}]
# Step: 11, Action: [[ 0.24673909  0.1565561   0.22488707  0.35635626  0.54861414  0.5911258
#    0.58352244  0.6702789   0.42199117  0.32496792 -0.44385716 -0.16742581
#   -0.16301791 -0.29037437 -0.3380748  -0.29033422 -0.46497494 -0.37848026
#   -0.17251197 -0.2612356  -0.00776707]], Reward: [20.827478], Done: [False], Info: [{'step': 2, 'efficiency': 23.445128471045184, 'cl': 0.12306187294100612, 'TimeLimit.truncated': False}]
# Step: 12, Action: [[ 0.31286314  0.22027779  0.30572113  0.37058932  0.58660084  0.5995917
#    0.5708149   0.65153813  0.43559653  0.33836883 -0.5149218  -0.19550315
#   -0.20358922 -0.32937402 -0.35244817 -0.3069829  -0.50699145 -0.40276125
#   -0.19364019 -0.29928103  0.02528458]], Reward: [26.14437], Done: [False], Info: [{'step': 3, 'efficiency': 26.44216285258309, 'cl': 0.17620296758645482, 'TimeLimit.truncated': False}]
# Step: 13, Action: [[ 0.3731104   0.27315634  0.38031673  0.38057774  0.62507683  0.61015385
#    0.5598606   0.6312914   0.4477114   0.3494159  -0.575692   -0.21973807
#   -0.24174155 -0.3636018  -0.36533183 -0.3197953  -0.54761523 -0.42461473
#   -0.21482725 -0.33656254  0.05900588]], Reward: [22.90622], Done: [False], Info: [{'step': 4, 'efficiency': 23.02856592209204, 'cl': 0.21632016989116565, 'TimeLimit.truncated': False}]
# Step: 14, Action: [[ 0.42758438  0.31582493  0.4483604   0.38619947  0.6629671   0.6214111
#    0.5497822   0.6092875   0.45788878  0.357535   -0.62706214 -0.24052715
#   -0.27718183 -0.39306542 -0.3765349  -0.32888067 -0.58640116 -0.44371915
#   -0.23542948 -0.37234887  0.09302974]], Reward: [16.097383], Done: [False], Info: [{'step': 5, 'efficiency': 16.388954645603164, 'cl': 0.22995902671223356, 'TimeLimit.truncated': False}]
# Step: 15, Action: [[ 0.47646758  0.34921277  0.5097265   0.3876431   0.6994893   0.6323386
#    0.5401977   0.5856441   0.46590185  0.3624465  -0.66988105 -0.25826877
#   -0.30965763 -0.41783467 -0.3859843  -0.33444652 -0.6230598  -0.4599737
#   -0.25506026 -0.40601692  0.1269041 ]], Reward: [8.100507], Done: [False], Info: [{'step': 6, 'efficiency': 8.138281209131733, 'cl': 0.18474816379155712, 'TimeLimit.truncated': False}]
# Step: 16, Action: [[ 0.51994735  0.37431398  0.5643881   0.38524693  0.73402494  0.64216226
#    0.53091896  0.56064403  0.47165364  0.3640893  -0.7049266  -0.27332637
#   -0.3389759  -0.4380357  -0.39367214 -0.33675393 -0.6573692  -0.4734077
#   -0.27345115 -0.43709525  0.16015589]], Reward: [1.3164303], Done: [False], Info: [{'step': 7, 'efficiency': 1.8398529903240568, 'cl': 0.07062420476263254, 'TimeLimit.truncated': False}]
# Step: 17, Action: [[ 0.5582067   0.39208248  0.61240184  0.37942114  0.7660797   0.65030867
#    0.5218057   0.5346272   0.47513828  0.362563   -0.73291415 -0.28602153
#   -0.3650169  -0.45385197 -0.3996333  -0.33609566 -0.68915015 -0.48412734
#   -0.29038402 -0.46527743  0.19234209]], Reward: [-0.26315883], Done: [False], Info: [{'step': 8, 'efficiency': -1.3607344114152058, 'cl': -0.08662013569139904, 'TimeLimit.truncated': False}]
# Step: 18, Action: [[ 0.5914534   0.4034145   0.65393275  0.37062466  0.79529685  0.6564004
#    0.5127334   0.5079545   0.47643408  0.3580888  -0.75452584 -0.29664633
#   -0.3877435  -0.46553016 -0.40394384 -0.3327894  -0.71828187 -0.49229175
#   -0.30567762 -0.4904169   0.22308624]], Reward: [-0.04399698], Done: [False], Info: [{'step': 9, 'efficiency': -2.538608903800525, 'cl': -0.2502915993417809, 'TimeLimit.truncated': False}]
# Step: 19, Action: [[ 0.61995006  0.4091612   0.6892765   0.35935473  0.8214766   0.6602534
#    0.5036047   0.4809931   0.47569978  0.35097682 -0.77043647 -0.30547774
#   -0.4072038  -0.4733816  -0.40672284 -0.32717353 -0.7447228  -0.4981001
#   -0.31919682 -0.5125075   0.25210023]], Reward: [-0.0025913], Done: [ True], Info: [{'step': 10, 'efficiency': -2.8110046362559276, 'cl': -0.39114884285980445, 'episode': {'r': -4.917358, 'l': 10, 't': 26.507693}, 'TimeLimit.truncated': False, 'terminal_observation': {'airfoil': array([ 0.74517167,  0.5463917 ,  0.7791178 ,  0.657178  ,  1.1128412 ,
#         1.0375639 ,  0.920942  ,  0.98809373,  0.78035265,  0.6217882 ,
#        -1.0233698 , -0.45671418, -0.52216727, -0.68075424, -0.6617374 ,
#        -0.5774704 , -0.994126  , -0.7614814 , -0.46190193, -0.67058915,
#         0.16263144], dtype=float32), 'cl_target': array([0.2], dtype=float32), 'boxes': array([0.56841177, 0.0179875 , 0.35589823, 0.08200756], dtype=float32)}}]
